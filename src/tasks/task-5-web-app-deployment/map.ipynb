# %%
import pandas as pd
import geopandas as gpd
import os
import pickle as pkl
import folium as flm

# %%
map_url = 'src/tasks/task-5-web-app-deployment/data/mapping_data.parquet'
dataframes = get_map_data(map_url)

# %%
cond = data[data['Province'] == name]

lat = data[cond]['Latitude'].tolist()

# %%
prov1 = df1[df1['Province'] == name]
prov1
# Out:
#                    City Province  Hospital  Infirmary  \
# 0               Aborlan  Palawan       1.0        0.0
# 13              Agutaya  Palawan       0.0        0.0
# 72              Araceli  Palawan       0.0        0.0
# 118             Balabac  Palawan       0.0        0.0
# 186            Bataraza  Palawan       1.0        1.0
# 243   Buadiposo-Buntong  Palawan       0.0        0.0
# 276               Butig  Palawan       0.0        0.0
# 295      Cagayan De Oro  Palawan      11.0        0.0
# 400         Cortes (BL)  Palawan       0.0        1.0
# 408            Currimao  Palawan       0.0        0.0
# 411       Daan Bantayan  Palawan       0.0        1.0
# 484             Dumarao  Palawan       1.0        0.0
# 490         El Salvador  Palawan       0.0        0.0
# 641              Kalibo  Palawan       5.0        0.0
# 751            Lingayen  Palawan       2.0        1.0
# 827           Magsingal  Palawan       1.0        0.0
# 978            Narvacan  Palawan       1.0        0.0
# 1149               Pugo  Palawan       0.0        0.0
# 1159        Quezon (QN)  Palawan       1.0        5.0
# 1178         Rizal (ZN)  Palawan       0.0        0.0
# 1193           Sabangan  Palawan       0.0        0.0
# 1338              Sapad  Palawan       0.0        0.0
# 1391         Sogod (CU)  Palawan       4.0        3.0
# 1538        Taytay (RL)  Palawan       4.0        1.0
#
#       Barangay Health Station  Rural Health Unit  COVID Testing Lab  \
# 0                        18.0                1.0                0.0
# 13                        7.0                1.0                0.0
# 72                       12.0                1.0                0.0
# 118                       9.0                1.0                0.0
# 186                      22.0                1.0                0.0
# 243                       3.0                1.0                0.0
# 276                       2.0                1.0                0.0
# 295                      33.0               27.0                5.0
# 400                      15.0                2.0                0.0
# 408                       2.0                1.0                0.0
# 411                      19.0                2.0                0.0
# 484                      11.0                1.0                0.0
# 490                      16.0                1.0                0.0
# 641                      17.0                2.0                1.0
# 751                      32.0                2.0                0.0
# 827                       8.0                1.0                0.0
# 978                       8.0                1.0                0.0
# 1149                      5.0                1.0                0.0
# 1159                     96.0                6.0                0.0
# 1178                     32.0                5.0                0.0
# 1193                     15.0                1.0                0.0
# 1338                      5.0                1.0                0.0
# 1391                     25.0                2.0                0.0
# 1538                     69.0                9.0                0.0
#
#       Poverty_Incidents  Population  Cluster_Id Vulnerability   Longitude  \
# 0                 13.33       35091           2        medium  118.548417
# 13                15.22       12545           1          high  120.939456
# 72                19.18       14909           1          high  119.989147
# 118               29.74       40142           1          high  117.064731
# 186               15.29       75468           2        medium  117.628693
# 243               66.88       16130           2        medium  117.838979
# 276               80.72       19302           1          high  119.939685
# 295               15.20        7242           1          high  121.197154
# 400               12.50       16954           1          high  120.205174
# 408                4.30       12184           2        medium  120.022097
# 411               17.80       84430           2        medium  121.008475
# 484                8.19       49506           2        medium  119.769202
# 490               13.33       41606           2        medium  119.390485
# 641                6.90       89127           2        medium  118.772224
# 751                8.58      107728           2        medium  119.867499
# 827                4.42       30792           2        medium  121.049757
# 978                6.21       44006           2        medium  118.403902
# 1149               3.16      108836           2        medium  118.757570
# 1159               4.02       14779           2        medium  117.996381
# 1178              11.87       15052           2        medium  117.646778
# 1193              14.04        9315           2        medium  119.343004
# 1338              25.10       67630           2        medium  119.256940
# 1391              27.22       33580           1          high  117.994111
# 1538              17.88      319104           0           low  119.515920
#
#        Latitude                                               Geom
# 0      9.437101  MULTIPOLYGON (((118.57997900000032 9.372150000...
# 13    11.151182  MULTIPOLYGON (((120.94799000000023 11.09447000...
# 72    10.553552  MULTIPOLYGON (((119.96452331600005 10.52233982...
# 118    7.986453  MULTIPOLYGON (((117.31555199900015 7.510830000...
# 186    8.673305  MULTIPOLYGON (((117.26072700000009 8.404679999...
# 243    8.773602  POLYGON ((117.63318634100017 8.819089889000054...
# 276   12.133569  MULTIPOLYGON (((119.83278700100016 11.98181000...
# 295    9.576908  MULTIPOLYGON (((120.82389100000012 9.281667001...
# 400   11.998606  MULTIPOLYGON (((120.11446400000011 11.66254000...
# 408   11.890532  MULTIPOLYGON (((119.97164200000009 11.71636000...
# 411   10.855122  MULTIPOLYGON (((121.04499053900008 10.80846786...
# 484   10.529045  MULTIPOLYGON (((119.60961914100005 10.43233966...
# 490   11.180008  MULTIPOLYGON (((119.3722230000003 11.008060000...
# 641    9.742915                                                NaN
# 751   11.490343  MULTIPOLYGON (((119.68472300000019 11.24528000...
# 827   10.865260  MULTIPOLYGON (((121.06655900000021 10.75644000...
# 978    9.269477  MULTIPOLYGON (((118.15693700000008 9.114720001...
# 1149   9.742050  MULTIPOLYGON (((118.3791580200002 9.6491603850...
# 1159   9.237736  MULTIPOLYGON (((117.78373718300008 9.093250275...
# 1178   9.018115  MULTIPOLYGON (((117.25875091600005 8.572079658...
# 1193  10.319627  MULTIPOLYGON (((119.2247009990001 10.063040000...
# 1338  10.527736  MULTIPOLYGON (((118.95054599900016 10.33333000...
# 1391   8.958755  MULTIPOLYGON (((118.25681304900002 8.885325433...
# 1538  10.826403  MULTIPOLYGON (((119.43502030500008 10.66193961...

# %%
name = 'Palawan'

# %%
prov = df1['Province'] == name
test = df1[prov]['Latitude'].tolist()

# %%
df1 = pd.read_csv('../task-5-web-app-deployment/data/mapping_data.csv')

# %%
def map_ph(data, name):
    cond = data['Province'] == name

    lat = data[cond]['Latitude'].tolist()
    lon = data[cond]['Longitude'].tolist()
    nam = data[cond]['City'].tolist()
    vul = data[cond]['Vulnerability'].tolist()
    pop = data[cond]['Population'].tolist()
    pov = data[cond]['Poverty_Incidents'].tolist()
    hop = data[cond]['Hospital'].tolist()

    html = '''<h4>Needs Assessment Information</h4>
    <b>City/Town: %s</b> <br /><br />
    <b>Vulnerability: </b> %s <br />
    <b>Population: </b> %s <br />
    <b>Poverty_Incidents: </b> %s <br />
    <b>Hospital: </b> %s <br />
    '''

    if lat and lon:
        map = flm.Map(location=[lat[0], lon[0]], zoom_start=6, zoom_control=True, zoom_end=20, scrollWheelZoom=False)
    else:
        return None

    fg = flm.FeatureGroup(name='Philippines Map')

    marker_props = {'low': {'color': 'red', 'size': 10},
                'medium': {'color': 'blue', 'size': 15},
                'high': {'color': 'green', 'size': 20}}

    for lt, ln, nm, vu, po, pv, ho in zip((lat), (lon), (nam), (vul), (pop), (pov), (hop)):
        iframe = flm.IFrame(html = html % ((nm), (vu), (po), (pv), (ho)), height = 165)
        popup = flm.Popup(iframe, min_width=200, max_width=500)
        props = marker_props[vu]
        marker = flm.CircleMarker(location = [lt, ln], popup = popup, fill_color=props['color'], color='None', radius=props['size'], fill_opacity = 0.7)
        fg.add_child(marker)
        map.add_child(fg)
        # print(len(vul))
        # print(marker_sized)
    # map.save('map.html')
    return map

# %%
map_ph(df1, 'Palawan')
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4f45ef759c9b8316f620e242c1a7601e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4f45ef759c9b8316f620e242c1a7601e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4f45ef759c9b8316f620e242c1a7601e = L.map(
#                 &quot;map_4f45ef759c9b8316f620e242c1a7601e&quot;,
#                 {
#                     center: [9.4371009, 118.5484168],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                     zoomEnd: 20,
#                     scrollWheelZoom: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3d7472a4a23c2d34288a3efe3aeeb637 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_4f45ef759c9b8316f620e242c1a7601e);
#
#
#             var feature_group_7a03c10f937ed0029fbdd2464068cdde = L.featureGroup(
#                 {}
#             ).addTo(map_4f45ef759c9b8316f620e242c1a7601e);
#
#
#             var circle_marker_30e0f36782e36570fee8816ca6c942a6 = L.circleMarker(
#                 [9.4371009, 118.5484168],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;None&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 15, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(feature_group_7a03c10f937ed0029fbdd2464068cdde);
#
#
#         var popup_5e093f74009dc61d7c33f912cc8f5be6 = L.popup({&quot;maxWidth&quot;: 500, &quot;minWidth&quot;: 200});
#
#
#
#                 var i_frame_afa241d7383ed7b35657e553507bf21b = $(`&lt;iframe src=&quot;data:text/html;charset=utf-8;base64,&quot; width=&quot;100%&quot; style=&quot;border:none !important;&quot; height=&quot;165&quot;&gt;&lt;/iframe&gt;`)[0];
#                 popup_5e093f74009dc61d7c33f912cc8f5be6.setContent(i_frame_afa241d7383ed7b35657e553507bf21b);
#
#
#
#         circle_marker_30e0f36782e36570fee8816ca6c942a6.bindPopup(popup_5e093f74009dc61d7c33f912cc8f5be6)
#         ;
#
#
#
#
#             var circle_marker_0d33490e226d2873f89200b7b8df0d53 = L.circleMarker(
#                 [11.1511823, 120.9394557],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;None&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 20, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(feature_group_7a03c10f937ed0029fbdd2464068cdde);
#
#
#         var popup_462d6e710773533da481841a05ea3bdb = L.popup({&quot;maxWidth&quot;: 500, &quot;minWidth&quot;: 200});
#
#
#
#                 var i_frame_1b9c9dce5613079c24189a98f1c879bd = $(`&lt;iframe src=&quot;data:text/html;charset=utf-8;base64,&quot; width=&quot;100%&quot; style=&quot;border:none !important;&quot; height=&quot;165&quot;&gt;&lt;/iframe&gt;`)[0];
#                 popup_462d6e710773533da481841a05ea3bdb.setContent(i_frame_1b9c9dce5613079c24189a98f1c879bd);
#
#
#
#         circle_marker_0d33490e226d2873f89200b7b8df0d53.bindPopup(popup_462d6e710773533da481841a05ea3bdb)
#         ;
#
#
#
#
#             var circle_marker_b0bfb008e69af92d3d0b70d7dadb91ad = L.circleMarker(
#                 [10.5535521, 119.9891472],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;None&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &qu

# %%
# gdf = dataframes[0]
df1 = dataframes[1]

# st.dataframe(gdf)
st.dataframe(df1)

# Add map.
def map_ph(data, name):
cond = data[data['Province'] == name]

lat = data[cond]['Latitude'].tolist()
lon = data[cond]['Longitude'].tolist()
nam = data[cond]['City'].tolist()
vul = data[cond]['Vulnerability'].tolist()
pop = data[cond]['Population'].tolist()
pov = data[cond]['Poverty_Incidents'].tolist()
hop = data[cond]['Hospital'].tolist()

html = '''<h4>Needs Assessment Information</h4>
<b>City/Town: %s</b> <br /><br />
<b>Vulnerability: </b> %s <br />
<b>Population: </b> %s <br />
<b>Poverty_Incidents: </b> %s <br />
<b>Hospital: </b> %s <br />
'''

if lat and lon:
    map = flm.Map(location=[lat[0], lon[0]], zoom_start=6, zoom_control=True, zoom_end=20, scrollWheelZoom=False)
        else:
            return None

    fg = flm.FeatureGroup(name='Philippines Map')

    for lt, ln, nm, vu, po, pv, ho in zip((lat), (lon), (nam), (vul), (pop), (pov), (hop)):
        sum_values = vu + po + pv + ho

        def marker_size(sums):
            marker_sized = 0
            if sums > 0:
                marker_sized = (10 - sums) + 10
            marker_sized = marker_sized * map.zoom_start / 12
            return int(marker_sized)

        def marker_color(sums):
            norm = colors.Normalize(vmin=0, vmax=10)
            cmap = cm.get_cmap('YlOrRd')
            marker_colored = cmap(norm(sums))
            return marker_colored

            iframe = flm.IFrame(html = html % ((nm), (vu), (po), (pv), (ho)), height = 165)
            popup = flm.Popup(iframe, min_width=200, max_width=500)
            marker = flm.CircleMarker(location = [lt, ln], popup = (popup), fill_color=marker_color(sum_values), color='None', radius=marker_size(sum_values, map.zoom_level), fill_opacity = 0.7)
            marker.add_child(flm.Popup(html = html % ((nm), (vu), (po), (pv), (ho)), min_width=200, max_width=500))
            fg.add_child(flm.CircleMarker(location = [lt, ln], popup = (popup), fill_color=marker_color(sum_values), color='None', radius=marker_size(sum_values), fill_opacity = 0.7))
            map.add_child(fg)
            print(sum_values)
            print(marker_size(sum_values))
        # map.save('map.html')
        return map
